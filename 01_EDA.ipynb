# %% [markdown]
# <a href="https://colab.research.google.com/github/omar-tueme/ciencia-de-datos-avanzada-mek-enero-2026/blob/main/01_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the libraries to be used

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %% [markdown]
# # Importing the dataset

# %%
url = 'https://raw.githubusercontent.com/omar-tueme/ciencia-de-datos-avanzada-mek-enero-2026/main/datos_info/adolescentes_ensanut2024_w.csv'
df = pd.read_csv(url, sep=';')

# %% [markdown]
# # Keeping only the columns that will be used

# %%
columns_to_keep = ['FOLIO_I', 'FOLIO_INT', 'd0810', 'd0801', 'd0309', 'd0709',
                   'd0702', 'd0701', 'd06a10', 'd06a9', 'd06a8', 'd06a7', 'd06a6',
                   'd06a5', 'd06a4', 'd06a3', 'd06a2', 'd06a1', 'd0818', 'd0817',
                   'd0601g', 'd0601f', 'd0601e', 'd0601d', 'd0601c', 'd0601b',
                   'd0601a', 'd0422', 'd0421', 'd0313', 'd02o1d', 'd02o1c', 'd02o1b',
                   'd02o1a', 'd01a08h', 'd01a08i', 'd01a08g', 'd01a08f', 'd01a08e',
                   'd01a08d', 'd01a08c', 'd01a08b', 'd01a08a', 'd01a03d', 'd01a03c',
                   'd01a03b', 'd01a03a', 'd0108', 'd0107', 'd0101', 'sexo', 'edad',
                   'd0416', 'd0415']

df_clean = df[columns_to_keep]

# %%
dictionary_non_id_variables = {
    'd0702': {
        'Question': '¿Cómo fue que te accidentaste?',
        1: 'Choque entre vehículos de 4 o más ruedas',
        2: 'Choque en motocicleta',
        3: 'Choque o atropellamiento como ciclista',
        4: 'Atropellado como peatón',
        5: 'Otros accidentes de transporte: avión, tren, lancha',
        6: 'Caída a nivel de piso',
        7: 'Golpe con objeto, equipo o maquinaria',
        8: 'Caída de un nivel a otro: silla, escalera, etc.',
        9: 'Golpe, rasguño o mordida de persona o animal (caballo, perro, etc.)',
        10: 'Exposición a corriente eléctrica, radiación',
        11: 'Exposición a humo o fuego',
        12: 'Contacto con superficies o sustancias calientes (quemaduras)',
        13: 'Exposición a fuerzas de la naturaleza: rayo, granizo',
        14: 'Picadura de animal ponzoñoso o contacto con plantas venenosas',
        15: 'Envenenamiento accidental: alimentos, medicamentos',
        16: 'Sumersión en depósitos de agua: alberca, cisterna',
        17: 'Otros accidentes que obstruyen la respiración: objeto extraño, alimento',
        18: 'Exposición accidental a otros factores',
        99: 'NS/NR'
    },
    'd0709': {
        'Question': '¿Qué problema de salud permanente te ocasionó el accidente?',
        1: 'Ningún problema',
        2: 'Limitación o dificultad para moverse o caminar (o lo hace con ayuda)',
        3: 'Limitación o dificultad para usar sus brazos y manos',
        4: 'Dificultad para oír',
        5: 'Dificultad para hablar',
        6: 'Dificultad para ver o ceguera',
        7: 'Otra limitación física o mental',
        99: 'NS/NR'
    },
    'd0309': {
        'Question': '¿Fuiste presionada(o) o forzada(o) para tener esa primera relación sexual?',
        1: 'Sí',
        2: 'No',
        9: 'No recuerdo'
    },
    'd0801': {
        'Question': 'En los últimos 12 meses, ¿sufriste algún daño a tu salud por robo, agresión o violencia?',
        1: 'Sí',
        2: 'No',
        9: 'No responde'
    },
    'd0810': {
        'Question': '¿A lo largo de tu vida, alguien te manoseó, tocó o acarició alguna parte de tu cuerpo o tuvo relaciones sexuales contigo cuando eras muy pequeño/a?',
        1: 'Sí, antes de los 12',
        2: 'Sí, cuando tenía 12 o más años',
        3: 'No, nunca',
        4: 'No recuerda',
        5: 'No responde'
    }
}

# %% [markdown]
# # General descriptive information

# %%
df_clean.head()
# Out:
#          FOLIO_I         FOLIO_INT  d0810  d0801 d0309 d0709 d0702  d0701  \
# 0  2024_01001001  2024_01001001_05      3      2                        2
# 1  2024_01001006  2024_01001006_03      1      2     2                  2
# 2  2024_01001009  2024_01001009_03      9      2                        2
# 3  2024_01001024  2024_01001024_03      3      2                        2
# 4  2024_01001026  2024_01001026_03      3      2     2                  2
#
#    d06a10  d06a9  ...  d01a03c  d01a03b  d01a03a  d0108  d0107  d0101  sexo  \
# 0       1      1  ...                                 6      4      3     2
# 1       1      1  ...        2        2        2      3      3      3     2
# 2       1      1  ...        2        2        2      2      3      3     1
# 3       1      1  ...        2        2        2      2      3      2     1
# 4       1      1  ...        2        2        2      3      2      3     1
#
#    edad d0416  d0415
# 0    11     2      1
# 1    19
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3730 entries, 0 to 3729
# Data columns (total 54 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FOLIO_I    3730 non-null   object
#  1   FOLIO_INT  3730 non-null   object
#  2   d0810      3730 non-null   int64
#  3   d0801      3730 non-null   int64
#  4   d0309      3730 non-null   object
#  5   d0709      3730 non-null   object
#  6   d0702      3730 non-null   object
#  7   d0701      3730 non-null   int64
#  8   d06a10     3730 non-null   int64
#  9   d06a9      3730 non-null   int64
#  10  d06a8      3730 non-null   int64
#  11  d06a7      3730 non-null   int64
#  12  d06a6      3730 non-null   int64
#  13  d06a5      3730 non-null   int64
#  14  d06a4      3730 non-null   int64
#  15  d06a3      3730 non-null   int64
#  16  d06a2      3730 non-null   int64
#  17  d06a1      3730 non-null   int64
#  18  d0818      3730 non-null   object
#  19  d0817      3730 non-null   int64
# ...

# %%
for col in df_clean.columns:
    print(f'Variable: {col}.\nNumber unique values: {df_clean[col].nunique()}.\n{df_clean[col].value_counts()}\n\n')
# Out:
# Variable: FOLIO_I.
# Number unique values: 3730.
# FOLIO_I
# 2024_32056030    1
# 2024_01001001    1
# 2024_32052016    1
# 2024_32052015    1
# 2024_32052014    1
#                 ..
# 2024_01001032    1
# 2024_01001028    1
# 2024_01001026    1
# 2024_01001024    1
# 2024_01001009    1
# Name: count, Length: 3730, dtype: int64
#
#
# Variable: FOLIO_INT.
# Number unique values: 3730.
# FOLIO_INT
# 2024_32056030_03    1
# 2024_01001001_05    1
# 2024_32052016_04    1
# 2024_32052015_05    1
# 2024_32052014_04    1
#                    ..
# 2024_01001032_02    1
# 2024_01001028_04    1
# 2024_01001026_03    1
# 2024_01001024_03    1
# 2024_01001009_03    1
# Name: count, Length: 3730, dtype: int64
#
#
# Variable: d0810.
# Number unique values: 5.
# d0810
# 3    3510
# 1     121
# 2      43
# 8      38
# 9      18
# Name: count, dtype: int64
#
#
# Variable: d0801.
# Number unique values: 3.
# d0801
# 2    3660
# 1      68
# 9       2
# Name: count, dtype: int64
#
#
# Variable: d0309.
# ...

# %%
df_clean.replace(r'^\s*$', np.nan, regex=True, inplace=True)
# Out:
# /tmp/ipython-input-2997930591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3730 entries, 0 to 3729
# Data columns (total 54 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FOLIO_I    3730 non-null   object
#  1   FOLIO_INT  3730 non-null   object
#  2   d0810      3730 non-null   int64
#  3   d0801      3730 non-null   int64
#  4   d0309      634 non-null    object
#  5   d0709      250 non-null    object
#  6   d0702      253 non-null    object
#  7   d0701      3730 non-null   int64
#  8   d06a10     3730 non-null   int64
#  9   d06a9      3730 non-null   int64
#  10  d06a8      3730 non-null   int64
#  11  d06a7      3730 non-null   int64
#  12  d06a6      3730 non-null   int64
#  13  d06a5      3730 non-null   int64
#  14  d06a4      3730 non-null   int64
#  15  d06a3      3730 non-null   int64
#  16  d06a2      3730 non-null   int64
#  17  d06a1      3730 non-null   int64
#  18  d0818      251 non-null    object
#  19  d0817      3730 non-null   int64
# ...

# %%
for col in df_clean.columns:
    print(f'Variable: {col}.\nNumber unique values: {df_clean[col].nunique()}.\n{df_clean[col].value_counts()}\n\n')
# Out:
# Variable: FOLIO_I.
# Number unique values: 3730.
# FOLIO_I
# 2024_32056030    1
# 2024_01001001    1
# 2024_32052016    1
# 2024_32052015    1
# 2024_32052014    1
#                 ..
# 2024_01001032    1
# 2024_01001028    1
# 2024_01001026    1
# 2024_01001024    1
# 2024_01001009    1
# Name: count, Length: 3730, dtype: int64
#
#
# Variable: FOLIO_INT.
# Number unique values: 3730.
# FOLIO_INT
# 2024_32056030_03    1
# 2024_01001001_05    1
# 2024_32052016_04    1
# 2024_32052015_05    1
# 2024_32052014_04    1
#                    ..
# 2024_01001032_02    1
# 2024_01001028_04    1
# 2024_01001026_03    1
# 2024_01001024_03    1
# 2024_01001009_03    1
# Name: count, Length: 3730, dtype: int64
#
#
# Variable: d0810.
# Number unique values: 5.
# d0810
# 3    3510
# 1     121
# 2      43
# 8      38
# 9      18
# Name: count, dtype: int64
#
#
# Variable: d0801.
# Number unique values: 3.
# d0801
# 2    3660
# 1      68
# 9       2
# Name: count, dtype: int64
#
#
# Variable: d0309.
# ...
